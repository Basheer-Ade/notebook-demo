# %%
#Q1: Create a list of student
students = ["Michael", "Vivian", "Kayode", "Tope", "Louis"]

# %%
print(students[:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(students[:])
#
# TypeError: 'tuple' object is not callable
