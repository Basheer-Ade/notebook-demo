# %%
import sys
sys.path.append("C:/Users/hp/Desktop\notebook-demo") 

import calculator_utils

print ("Add:", calculator_utils.add(8, 5))
print ("Subtract:", calculator_utils.subtract(8, 5))
print ("Multiply:", calculator_utils.multiply(8, 5))
print ("Divide:", calculator_utils.divide(8, 2))
# Out:
# Add: 13
# Subtract: 3
# Multiply: 40
# Divide: 4.0
