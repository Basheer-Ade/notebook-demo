# %% [markdown]
# # Task 1: Optimising Python Code

# %%
def get_unique_items(lst):
    unique = []
    for item in lst:
        if item not in unique:
            unique.append(item)
    return unique

# %%
#Using Set()
